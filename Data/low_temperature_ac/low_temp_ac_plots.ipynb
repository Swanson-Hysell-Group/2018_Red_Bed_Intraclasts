# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import matplotlib.colors as colors

# %%
BRIC_20c_raw = pd.read_csv('BRIC_20c_ac_raw.csv')
BRIC_20c_modeled = pd.read_csv('BRIC_20c_ac_modeled.csv')
BRIC_31c_raw = pd.read_csv('BRIC_31c_ac_raw.csv')
BRIC_31c_modeled = pd.read_csv('BRIC_31c_ac_modeled.csv')
BRIC_22c_raw = pd.read_csv('BRIC_22c_ac_raw.csv')
BRIC_22c_modeled = pd.read_csv('BRIC_22c_ac_modeled.csv')
BRIC_26c_raw = pd.read_csv('BRIC_26c_ac_raw.csv')
BRIC_26c_modeled = pd.read_csv('BRIC_26c_ac_modeled.csv')
BRIC_26c_modeled.columns
# Out:
# Index(['T [K]', 'X'(1.0Hz)', 'X', 'X'(5.6Hz)', 'X.1', 'X'(31.6Hz)', 'X.2',
#        'X'(177.6Hz)', 'X.3', 'X'(997.3Hz)',
#        ...
#        'X.116', 'Series118', 'X.117', 'Series119', 'X.118', 'Series120',
#        'X.119', 'Series121', 'X.120', 'Series122'],
#       dtype='object', length=244)

# %%
viridis = cm = plt.get_cmap('viridis') 
cNorm  = matplotlib.colors.LogNorm(vmin=1, vmax=1000)
# scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='viridis_r')
scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='viridis')

# for n in poles.index:
#     rgba = scalarMap.to_rgba(poles.AgeNominal[n])
#     hex_color = colors.rgb2hex(rgba)
    
color_1 = scalarMap.to_rgba(1)
color_1_hex = colors.rgb2hex(color_1)
color_5_6 = scalarMap.to_rgba(5.6)
color_5_6_hex = colors.rgb2hex(color_5_6)
color_10 = scalarMap.to_rgba(10)
color_10_hex = colors.rgb2hex(color_10)
color_31 = scalarMap.to_rgba(31.6)
color_31_hex = colors.rgb2hex(color_31)
color_99 = scalarMap.to_rgba(99)
color_99_hex = colors.rgb2hex(color_99)
color_997 = scalarMap.to_rgba(997.3)
color_997_hex = colors.rgb2hex(color_997)

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,3,1)
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X'(99.9Hz)"],color=color_99_hex,label="$\chi$' 99.9 Hz")
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X'(10.0Hz)"],color=color_10_hex,label="$\chi$' 10.0 Hz")
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
#plt.title('in-phase')
plt.legend()
plt.subplot(2,3,2)
plt.plot(BRIC_20c_modeled['T [K]'],BRIC_20c_modeled["X'(99.9Hz)"],color=color_99_hex,label="$\chi$' 99.9 Hz")
plt.plot(BRIC_20c_modeled['T [K]'],BRIC_20c_modeled["X'(10.0Hz)"],color=color_10_hex,label="$\chi$' 10.0 Hz")
plt.plot(BRIC_20c_modeled['T [K]'],BRIC_20c_modeled["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
#plt.title('in-phase (paramagnetism removed)')
plt.legend()
plt.subplot(2,3,3)
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X''(99.9Hz)"],color=color_99_hex,label='$\chi$" 99.9 Hz')
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X''(10.0Hz)"],color=color_10_hex,label='$\chi$" 10.0 Hz')
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X''(1.0Hz)"],color=color_1_hex,label='$\chi$" 1.0 Hz')
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["-pi/2 dX/dln(f)(10.0Hz)"],linestyle='dotted',color='black',label='-$\pi$/2 d$\chi$/dln(f)\n(10.0Hz)')
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
ymin, ymax = plt.ylim()
plt.ylim(0,ymax)
#plt.title('out-of-phase')
plt.legend()

plt.subplot(2,3,4)
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["X'(99.9Hz)"],color=color_99_hex,label="$\chi$' 99.9 Hz")
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["X'(10.0Hz)"],color=color_10_hex,label="$\chi$' 10.0 Hz")
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
#plt.title('in-phase')
plt.legend()
plt.subplot(2,3,5)
plt.plot(BRIC_31c_modeled['T [K]'],BRIC_31c_modeled["X'(99.9Hz)"],color=color_99_hex,label="$\chi$' 99.9 Hz")
plt.plot(BRIC_31c_modeled['T [K]'],BRIC_31c_modeled["X'(10.0Hz)"],color=color_10_hex,label="$\chi$' 10.0 Hz")
plt.plot(BRIC_31c_modeled['T [K]'],BRIC_31c_modeled["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
#plt.title('in-phase (paramagnetism removed)')
plt.legend()
plt.subplot(2,3,6)
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["X''(99.9Hz)"],color=color_99_hex,label='$\chi$" 99.9 Hz')
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["X''(10.0Hz)"],color=color_10_hex,label='$\chi$" 10.0 Hz')
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["X''(1.0Hz)"],color=color_1_hex,label='$\chi$" 1.0 Hz')
plt.plot(BRIC_31c_raw['T [K]'],BRIC_31c_raw["-pi/2 dX/dln(f)(10.0Hz)"],linestyle='dotted',color='black',label='-$\pi$/2 d$\chi$/dln(f)\n(10.0Hz)')
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
ymin, ymax = plt.ylim()
plt.ylim(0,ymax)
#plt.title('out-of-phase')
plt.legend()
plt.tight_layout()

# %%
BRIC_22c_raw.columns
# Out:
# Index(['T [K]', 'X'(1.0Hz)', 'X''(1.0Hz)', 'X'(5.6Hz)', 'X''(5.6Hz)',
#        'X'(31.6Hz)', 'X''(31.6Hz)', 'X'(177.6Hz)', 'X''(177.6Hz)',
#        'X'(997.3Hz)', 'X''(997.3Hz)', '-pi/2 dX/dln(f)(5.6Hz)',
#        '-pi/2 dX/dln(f)(31.6Hz)', '-pi/2 dX/dln(f)(177.6Hz)'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,3,1)
plt.plot(BRIC_22c_raw['T [K]'],BRIC_22c_raw["X'(997.3Hz)"],color=color_997_hex,label="$\chi$' 997.3 Hz")
plt.plot(BRIC_22c_raw['T [K]'],BRIC_22c_raw["X'(31.6Hz)"],color=color_31_hex,label="$\chi$' 31.6 Hz")
plt.plot(BRIC_22c_raw['T [K]'],BRIC_22c_raw["X'(5.6Hz)"],color=color_5_6_hex,label="$\chi$' 5.6 Hz")
plt.plot(BRIC_22c_raw['T [K]'],BRIC_22c_raw["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
# #plt.title('in-phase')
plt.legend()
plt.subplot(2,3,2)
plt.plot(BRIC_22c_modeled['T [K]'],BRIC_22c_modeled["X'(997.3Hz)"],color=color_997_hex,label="$\chi$' 997.3 Hz")
plt.plot(BRIC_22c_modeled['T [K]'],BRIC_22c_modeled["X'(31.6Hz)"],color=color_31_hex,label="$\chi$' 31.6 Hz")
plt.plot(BRIC_22c_modeled['T [K]'],BRIC_22c_modeled["X'(5.6Hz)"],color=color_5_6_hex,label="$\chi$' 5.6 Hz")
plt.plot(BRIC_22c_modeled['T [K]'],BRIC_22c_modeled["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
#plt.title('in-phase (paramagnetism removed)')
plt.legend()
plt.subplot(2,3,3)
#plt.plot(BRIC_22c_raw['T [K]'],BRIC_22c_raw["X''(997.3Hz)"],color=color_997_hex,label='$\chi$" 997.3 Hz')
plt.plot(BRIC_22c_raw['T [K]'][1:],BRIC_22c_raw["X''(31.6Hz)"][1:],color=color_31_hex,label='$\chi$" 31.6 Hz')
plt.plot(BRIC_22c_raw['T [K]'][1:],BRIC_22c_raw["X''(5.6Hz)"][1:],color=color_5_6_hex,label='$\chi$" 5.6 Hz')
plt.plot(BRIC_22c_raw['T [K]'][1:],BRIC_22c_raw["X''(1.0Hz)"][1:],color=color_1_hex,label='$\chi$" 1.0 Hz')
plt.plot(BRIC_22c_raw['T [K]'][1:],BRIC_22c_raw["-pi/2 dX/dln(f)(5.6Hz)"][1:],linestyle='dotted',color='black',label='-$\pi$/2 d$\chi$/dln(f)\n(5.6Hz)')
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
ymin, ymax = plt.ylim()
plt.ylim(0,ymax*1.2)
#plt.title('out-of-phase')
plt.legend()

plt.subplot(2,3,4)
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(997.3Hz)"],color=color_997_hex,label="$\chi$' 997.3 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(31.6Hz)"],color=color_31_hex,label="$\chi$' 31.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(5.6Hz)"],color=color_5_6_hex,label="$\chi$' 5.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
# #plt.title('in-phase')
plt.legend()
plt.subplot(2,3,5)
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(997.3Hz)"],color=color_997_hex,label="$\chi$' 997.3 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(31.6Hz)"],color=color_31_hex,label="$\chi$' 31.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(5.6Hz)"],color=color_5_6_hex,label="$\chi$' 5.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
#plt.title('in-phase (paramagnetism removed)')
plt.legend()
plt.subplot(2,3,6)
#plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X''(997.3Hz)"],color=color_997_hex,label='$\chi$" 997.3 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["X''(31.6Hz)"][1:],color=color_31_hex,label='$\chi$" 31.6 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["X''(5.6Hz)"][1:],color=color_5_6_hex,label='$\chi$" 5.6 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["X''(1.0Hz)"][1:],color=color_1_hex,label='$\chi$" 1.0 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["-pi/2 dX/dln(f)(5.6Hz)"][1:],linestyle='dotted',color='black',label='-$\pi$/2 d$\chi$/dln(f)\n(5.6Hz)')
plt.ylabel('$\chi$ (m$^3$/kg)')
plt.xlabel('temperature (K)')
ymin, ymax = plt.ylim()
plt.ylim(0,ymax*1.1)
#plt.title('out-of-phase')
plt.legend()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'T [K]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f0b8fd475e73> in <module>()
#      10 plt.legend()
# ...

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,3,1)
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X'(99.9Hz)"],color=color_99_hex,label="$\chi$' 99.9 Hz")
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X'(10.0Hz)"],color=color_10_hex,label="$\chi$' 10.0 Hz")
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.ylabel('$\chi$ (m$^3$/kg)',fontsize=12)
plt.xlabel('temperature (K)',fontsize=12)
#plt.title('in-phase')
plt.text(300,0.00000105,'BRIC-20',horizontalalignment='right',verticalalignment='top',fontweight='bold',fontsize=18)
plt.legend()
plt.subplot(2,3,2)
plt.plot(BRIC_20c_modeled['T [K]'],BRIC_20c_modeled["X'(99.9Hz)"],color=color_99_hex,label="$\chi$' 99.9 Hz")
plt.plot(BRIC_20c_modeled['T [K]'],BRIC_20c_modeled["X'(10.0Hz)"],color=color_10_hex,label="$\chi$' 10.0 Hz")
plt.plot(BRIC_20c_modeled['T [K]'],BRIC_20c_modeled["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)',fontsize=12)
plt.xlabel('temperature (K)',fontsize=12)
plt.text(300,0.75E-7,'paramagnetism removed',horizontalalignment='right',verticalalignment='bottom',style='italic',fontsize=12)
#plt.title('in-phase (paramagnetism removed)')
ymin, ymax = plt.ylim()
plt.ylim(ymin-(0.15*ymin),ymax)
plt.legend()
plt.subplot(2,3,3)
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X''(99.9Hz)"],color=color_99_hex,label='$\chi$" 99.9 Hz')
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X''(10.0Hz)"],color=color_10_hex,label='$\chi$" 10.0 Hz')
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["X''(1.0Hz)"],color=color_1_hex,label='$\chi$" 1.0 Hz')
plt.plot(BRIC_20c_raw['T [K]'],BRIC_20c_raw["-pi/2 dX/dln(f)(10.0Hz)"],linestyle='dotted',color='black',label='-$\pi$/2 d$\chi$/dln(f)\n(10.0Hz)')
plt.ylabel('$\chi$ (m$^3$/kg)',fontsize=12)
plt.xlabel('temperature (K)',fontsize=12)
ymin, ymax = plt.ylim()
plt.ylim(0,ymax)
#plt.title('out-of-phase')
plt.legend()

plt.subplot(2,3,4)
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(997.3Hz)"],color=color_997_hex,label="$\chi$' 997.3 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(31.6Hz)"],color=color_31_hex,label="$\chi$' 31.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(5.6Hz)"],color=color_5_6_hex,label="$\chi$' 5.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.ylabel('$\chi$ (m$^3$/kg)',fontsize=12)
plt.xlabel('temperature (K)',fontsize=12)
# #plt.title('in-phase')
plt.text(300,0.0000012,'BRIC-26',horizontalalignment='right',verticalalignment='top',fontweight='bold',fontsize=18)
plt.legend()
plt.subplot(2,3,5)
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(997.3Hz)"],color=color_997_hex,label="$\chi$' 997.3 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(31.6Hz)"],color=color_31_hex,label="$\chi$' 31.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(5.6Hz)"],color=color_5_6_hex,label="$\chi$' 5.6 Hz")
plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_modeled["X'(1.0Hz)"],color=color_1_hex,label="$\chi$' 1.0 Hz")
plt.ylabel('$\chi$ (m$^3$/kg)',fontsize=12)
plt.xlabel('temperature (K)',fontsize=12)
#plt.title('in-phase (paramagnetism removed)')
plt.text(300,0.57E-7,'paramagnetism removed',horizontalalignment='right',verticalalignment='bottom',style='italic',fontsize=12)
plt.legend()
plt.subplot(2,3,6)
#plt.plot(BRIC_26c_raw['T [K]'],BRIC_26c_raw["X''(997.3Hz)"],color=color_997_hex,label='$\chi$" 997.3 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["X''(31.6Hz)"][1:],color=color_31_hex,label='$\chi$" 31.6 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["X''(5.6Hz)"][1:],color=color_5_6_hex,label='$\chi$" 5.6 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["X''(1.0Hz)"][1:],color=color_1_hex,label='$\chi$" 1.0 Hz')
plt.plot(BRIC_26c_raw['T [K]'][1:],BRIC_26c_raw["-pi/2 dX/dln(f)(5.6Hz)"][1:],linestyle='dotted',color='black',label='-$\pi$/2 d$\chi$/dln(f)\n(5.6Hz)')
plt.ylabel('$\chi$ (m$^3$/kg)',fontsize=12)
plt.xlabel('temperature (K)',fontsize=12)
ymin, ymax = plt.ylim()
plt.ylim(0,ymax*1.1)
#plt.title('out-of-phase')
#plt.tick_params(axis='both', which='major', labelsize=11)
plt.legend()
plt.tight_layout()
plt.savefig('low_temp_ac.pdf')
